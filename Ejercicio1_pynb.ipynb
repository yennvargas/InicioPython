# %% [markdown]
# <a href="https://colab.research.google.com/github/yennvargas/InicioPython/blob/main/Ejercicio1_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Crear una variable para almacenar el nombre del usuario y otra para su edad, para mostrar en la pantalla un mensaje de bienvenida.

# %%
  nombre = input("¿Cual es tu nombre? ")
  edad = int(input("¿Cual es tu edad? "))
  print(f"Hola, {nombre}! Tienes {edad} años")
# Out:
# ¿Cual es tu nombre? Yennifer
# ¿Cual es tu edad? 29
# Hola, Yennifer! Tienes 29 años

# %% [markdown]
# Crear una funcion que determine si el usuario es mayor de edad

# %%
def es_mayor_de _edad(edad):
  if edad >=18:
    return "Eres mayor de edad"
    else:
      return "Eres menor de edad"
      print(es_mayor_de_edad(edad))
# Out:
#   File "/tmp/ipykernel_3371/2744780325.py", line 1
#     def es_mayor_de _edad(edad):
#                     ^
# SyntaxError: expected '('

# %% [markdown]
# Los bucles en python se utilizan para ejecutar un bloque de codigo de forma repetida.
# El bucle for, se utiliza cuando sabaemos donde va a terminar la repeticion.
# El bucle while, se utiliza cuando NO sabemos donde va aterminar.

# %%
for recorrer in range(5):
  print(recorrer)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# Suarez Suares = S-0 u-1 a-2 r-3 e-4 z-5 - s
